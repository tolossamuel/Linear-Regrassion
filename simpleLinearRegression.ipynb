# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data_set = pd.read_csv("DataSets/train.csv")

# %%
data_set
# Out:
#       x          y
# 0    24  21.549452
# 1    50  47.464463
# 2    15  17.218656
# 3    38  36.586398
# 4    87  87.288984
# ..   ..        ...
# 694  58  58.595006
# 695  93  94.625094
# 696  82  88.603770
# 697  66  63.648685
# 698  97  94.975266
#
# [699 rows x 2 columns]

# %%
Test_data = pd.read_csv("DataSets/test.csv")

# %%
Test_data
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy = "mean")
# data_set["y"] = imputer.fit_transform(data_set[["y"]])
# creat the mode

model = LinearRegression()

# %%
# dependent variable and independent variable
X = data_set.iloc[:,:-1]
Y = data_set.iloc[:,-1]

# scatter data visual
plt.scatter(X,Y)

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
X_test = Test_data.iloc[:,:-1]
Y_test = Test_data.iloc[:,-1]
pred = model.predict(X_test)

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test,pred,color = "red")

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(Y_test,pred)
r2_score(Y_test, pred)
# Out:
# 0.9888014444327563
